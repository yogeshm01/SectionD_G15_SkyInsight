# %% [markdown]
# # 📥 Data Extraction
# Load and inspect raw dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/airline_reviews.csv')
df.head()

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()
